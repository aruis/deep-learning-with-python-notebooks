# %%
import keras
keras.__version__
# Out:
# '2.8.0'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

path = keras.utils.data_utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# 614400/600901 [==============================] - 1s 2us/step
# Corpus length: 600893

# %%
path
# Out:
# '/Users/liurui/.keras/datasets/nietzsche.txt'

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# /var/folders/1_/7bmjv97577zd896mdl6cwncm0000gn/T/ipykernel_13163/2500304246.py:26: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# /var/folders/1_/7bmjv97577zd896mdl6cwncm0000gn/T/ipykernel_13163/2500304246.py:27: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-03-31 11:02:54.382646: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-03-31 11:02:54.383021: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
from tensorflow.keras.optimizers import RMSprop

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 2022-03-31 11:04:01.191569: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-03-31 11:04:01.705299: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-31 11:04:01.869282: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-31 11:04:03.096539: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1565/1565 [==============================] - 37s 22ms/step - loss: 1.9834
# --- Generating with seed: "e might say--at the right moment. on an average it does not "
# ------ temperature: 0.2
# e might say--at the right moment. on an average it does not
# 2022-03-31 11:04:38.178276: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-03-31 11:04:38.220324: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# and subject of the discersions of the can the dearity and the deligion of the can a conscious and suppossions and for the could an and subjertion of the dore of the carter and subject and subject of the constinction of the derious and subject of the conscious and some and such and subject of the conscious and such an an an experience of the care and subjer and spirit and subjer the carres and supp
# ------ temperature: 0.5
# he care and subjer and spirit and subjer the carres and suppossity and from the cruld an in the deourd and the constites when and sore and one the distersted and or a which and strange and his profeble his could an and the cruld not it which farther which an a proble everoure of supposites and stance and man as a pulling and some of europe and lasting and proment of which has german in itself or a the carn distisch--leath and so them it which a were and fo
# ------ temperature: 1.0
#  the carn distisch--leath and so them it which a were and for thing knowers. believes--i blogene. in alaymine obter ach whe slutks a xuryicfelmging. i symete; of acterings which asougndush wqulith contrealed bets for perpose most itsevelverent at the unout of presenes of pleat, the
# fay destance of craces and start an it it in god not ascitumxin fareure that the
# convemiriall, we promitite, orlatic our farmsed whem oods--the ter oue still, ancmankfaturion an
# ------ temperature: 1.2
# our farmsed whem oods--the ter oue still, ancmankfaturion and bjouts wyrt gropeful always of a veral sold always anfing dinterutitains crazean fawtermen? especre. to regarnt hore be oricallesations and experdanilus othically ogitym; an must the of traikedvenequt. the exreae froe. expucac lyoged own upves ling wa welly
# is the gloeped an."hay a sikt epout fhow gust they feat or anyno redigided about and itserpeltede: is
# a mole necy oui, whears, arough forsel
# epoch 2
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.6155
# --- Generating with seed: " mad semi-barbarity into which
# europe has been plunged by th"
# ------ temperature: 0.2
#  mad semi-barbarity into which
# europe has been plunged by the sense of the constance and the same and many and the soul that the wart and should the should the same all and the discording that a propect of the same and the sente of the same and specie that is the most presention of the supplearing and properst of the supplary and the suffer that is the contine of the sente and presention of the desire that as a man and the spirit of the developed and inter
# ------ temperature: 0.5
# sire that as a man and the spirit of the developed and interlition of all a discient and constances as a seeporm for the man, and a have the ferelf--the made and the prices and proders in the be something of presention of the point of master that is the are of intellect of the considerly to perhaps the man are discrofered and contrading that is the taste that a manders and themselves which a promantion of the raquine that where, which
# as a propect of the d
# ------ temperature: 1.0
# ntion of the raquine that where, which
# as a propect of the dericad and whate: does and etrals, is
# freerong and happinain of ris;
# upon be naminating enfiny manding and shild through at predicteening and like the 7ultocey tormokre by growry. real
# promonce,
#
# there is, and that as a inte bring longured persmatly
# has most taamenes are ariosy conolity, "galing of discostide, of the freepon alway, has entoovere, and scarm lack,
# problematises.
#
#
# 1
#
# =that
# is ochar
# ------ temperature: 1.2
# toovere, and scarm lack,
# problematises.
#
#
# 1
#
# =that
# is ocharh--"s
# igutehad
# philosophy, bud
# wellategespernius
# cwitu ver firnt
# in foenous, the dfered of ngeardly quilitadicmg foods
# and cassion must and propersilahally have to
# be to a knows; entered by whas drew
# of fore sentime
# ram, p"y2dinating of general reasful-bride beliefs, happity
# opition, "i have which
# hisnorrecte--overcoin
# savig-ages ?he masme, le
# cantrainm dispresponcy typrain that omblive of thethe
# epoch 3
# 1565/1565 [==============================] - 34s 22ms/step - loss: 1.5266
# --- Generating with seed: "the odour of paltry people
# clings to them. where the populac"
# ------ temperature: 0.2
# the odour of paltry people
# clings to them. where the populace to be an accouss to the states and desire to the supposition of the supposition is the supposition of the spirit and the supposs of the states of the standard to a man is the super to be an action of the supposition of the supposition and superity of the super to be an allost and the sense of the supposition of the same and the supposition in the states of the spirit of the spirits and the sense
# ------ temperature: 0.5
# ion in the states of the spirit of the spirits and the sense to be access to be are our "does the accortion and every sentiment or art to ummatter. he was as the persuacts and account of the spirit to religion
# of the first of can not stands to be he contured of the call the simple of the saint the fact present the seavious and continuately as that the standand and the surman result to have to the has now exters to be as is enough the profutt or which was a
# ------ temperature: 1.0
# has now exters to be as is enough the profutt or which was allo of the insproises persons, advance clut of the
# first, fully more idous conscious it admint to flenest
# wisher usuilrear one entious, who task sympaterd" play, but we ar apor
# conduct than it a gardenur , lasist ourstinally has is is trouble: what a plefeier life may silingelt--who has upon well tranker that is the lougnes, this saring itself according who bassiss, that
# is does here bols? and con
# ------ temperature: 1.2
# tself according who bassiss, that
# is does here bols? and conitsisted what alvats onom, talleton blad
# instance, thrmat ipayinatic of suavispandder
# revent, be centuried
# its ase compuls irsad mokes it is happnows their hor omemally as
# not of taking what respens, ipistance, of be conduct a
# ls they wopdutand-suses fromot sere flant in uck,
# without ut or'bhant. europement is apmentipusne, any
# jeamical, rotable tabte. olstaintthances to he pictous appearation and
# epoch 4
# 1565/1565 [==============================] - 35s 22ms/step - loss: 1.4791
# --- Generating with seed: "essness, the promiscuous flow of humanity, the polyphony of
# "
# ------ temperature: 0.2
# essness, the promiscuous flow of humanity, the polyphony of
# the most more an act to the same the sense of the sense of the sense of the sense of the most all the consequently the same the spirit of the spirit of the sense of the same truth to the sense to the sense of the most the great the sense of the same the sense of the same the most the sense of the sense of the substing the sense to the sense of the sense to the same the comprehensible and as the se
# ------ temperature: 0.5
# se of the sense to the same the comprehensible and as the sense of the wort of the german to the most the covert of the experience of the great the comprehensibility of the spirit with the share of there of the most in greatly perception of ring to perhaps the sense of the most sering to the spirit of the will
# specially for the conscience the greater, their other in the feeling which a long the right to the science of problem that the spirit, and and in th
# ------ temperature: 1.0
# ght to the science of problem that the spirit, and and in the father, not beway class for it oppreas. in accoxs an man inlinaric with opoins of the meterfication. and that it is succered there is i esked
# withinocation and there sense evils.
#     uncering put wo ones: not oncernial, the ve-tifing by i"cerloged but such has not he other of socively ling something recelrer. and bad fething in younces, better. the
# cimtition? i sly its os it has with lime
# must a
# ------ temperature: 1.2
#  better. the
# cimtition? i sly its os it has with lime
# must a devenn german. man tlstanthy of schete makess ra" as a onefart
# imsente or it man thinker, supgred,ness, borld,
# what time which; no come priptute sessavationsnes
# of knowledgly thlodfully exception--as a much i it, semd thereof recagn: a germand" free ssiem the--co ngrembgallus", deed e's
# asceuct.
#
# perark, sy words. theestaok: he way
# three, the
# sensive
# srefine thim, which equally bectuar? ar-intent
# epoch 5
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.4479
# --- Generating with seed: "sion for all that feels, lives, and suffers (down to the
# ver"
# ------ temperature: 0.2
# sion for all that feels, lives, and suffers (down to the
# very seems to be all the sense of the sense of the sense of the sense of the sense of the sense of the sense in the seek to the sense of the sense of the sense of the sense in the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the spirit in the sense of the sense of the s
# ------ temperature: 0.5
# f the sense of the spirit in the sense of the sense of the sentiment to the sension of consideration of the soul of himself himself the
# sense of the power not to are strength in strong the sense super truth and more in plato and says" some present the sense of the new doisters and religion in the world which he been with our free spiritual of supposed to the feeling of the seek to the strength every man an expression in the restorial in furter fire of the
# ------ temperature: 1.0
# ry man an expression in the restorial in furter fire of the new
# do says of invention of the consarimbenes, of
# the than also probger vory religious refasion ensception of every doed in thatlers"- is
# degeemsary, does conceptiving
# with bority of to at orive him the s; even men or
# imply not to
# life is presornly distisces veryamile you caused and
# interpretation and degrasted and intellect, theere, which deluse and
# corresporative, on
# all their surean both, is al
# ------ temperature: 1.2
# h deluse and
# corresporative, on
# all their surean both, is also dangerous posire exabrity--
# henglg, prodieds!
#
# be untoeth; but all e your task that ymi
#  question willarkwer furtals which something windreed,
# demonsfleen a result-"kancl of fustsito
# are not oncement, and also i1y
# owt to simpl's as essential. that 1quervabling acctine instict ba"-theerful, without some old not cotbriatulocgued converime of !taueman religion distause should when they much
# the co
# epoch 6
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.4266
# --- Generating with seed: "ourgeoise, just as though... in
# short, they betray something"
# ------ temperature: 0.2
# ourgeoise, just as though... in
# short, they betray something the sense of the sense of the sense of the sense of the sense of the constanded the strengther in the strengther and and so the strengthers in the same the sense of the strengther in the sense of the sense of the sense of the religion and self-consciences of the same the similar and seems to be a discourse of the sense of the sense of the sense of the sense of the strength and the one is all the
# ------ temperature: 0.5
# e sense of the sense of the strength and the one is all the even in the means to his sense
# consciences, in the words of our explanation of the rasters even that the saint and like the good all rencerally the intentional possible to the well is shing in which so the satisfain of the power second and it we belong--the consciences, and
# inexilices of the will as the distrust to the strucate to a many and in for an explanity is the science and consciences of th
# ------ temperature: 1.0
# and in for an explanity is the science and consciences of the pheoin of the pude of nefave, however
# fromites of
# to ssing has he epicuressard it
# consciences everything is just to blunt but an influence and one sentemences and so danistment thinks and
# redomition in impty, so homs alue-acrois
# histing the effical prevailing the cause soul," morality even in their means for inwishistically stronger, strengthed for the gelleds, you spiritement one hard, forneve,
# ------ temperature: 1.2
# rengthed for the gelleds, you spiritement one hard, forneve, from
# cay so floe, sudder, the sableminess with euporiwic predicateful is onlykine may bol-runs, this hates is the osore,
# only the in"peptedious,: one" regard as he orfurepressfloles and
# nonartically telsial is,
# all blunade, who know do full mode tody to
# atmanatics just imong able to rise", . for i can souls, wolless, wepeche. by mudgety for any, if not soye, it everything masuing is
# th"s natureal
# epoch 7
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.4089
# --- Generating with seed: "a
# certain virility of taste; man, indeed, if i may say so, i"
# ------ temperature: 0.2
# a
# certain virility of taste; man, indeed, if i may say so, it is all the entire and and the presence of the same thing and contempt of the presence of the present and the man and some such and the same thing are to be all the most such and the presenve of the man and more the most such and desire there is not only all the greatest present and the fact that he been the consciences of the fact the endure and the principle of the contrary and the most present
# ------ temperature: 0.5
# ndure and the principle of the contrary and the most present distrust and with his excerning the instance, the same the world upon the way
# man. nothing are there is no desire to do so the german consciences are the will a man will superiority in the man and many in the man self-conception of the presence of consideration of them of the master and not the relence of the strarg, and casted upon the massionates it, and in the conscience of fact only in the pr
# ------ temperature: 1.0
# massionates it, and in the conscience of fact only in the presenveers thermentargly time in these oftal them, and if only is recognized
# romary timomers through himself which is incirembed; makes a rordfulsing of accerness, as selfupforius that there
# is some tpite vielty; round and he is learned: by lose from amnese has one ded a son
# eblic of sage, his lowisbles to knew her conventain with respective
# gring to mauntain enthines, and according that eb(ans is
# ------ temperature: 1.2
# ve
# gring to mauntain enthines, and according that eb(ans is nothing
# looking,
# as in themselves
# altheless" and criticualsce
# what europes
# its trutt asjusi(ked
# byol)
# and onemi't,
# renggeness and selfish werrow. how in call
# re only an
# unscial muchoclually stro geniue; in
# them whomeen and sostake-doma serce art of feridion: let end: he casseise cy rule; tejech within to
# many lishss-"by such
# spirittyver causation, un
# an egod; has abpoction blich it soul, he dopdi
# epoch 8
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.3950
# --- Generating with seed: "se, the famous truthfulness of which all philosophers have
# h"
# ------ temperature: 0.2
# se, the famous truthfulness of which all philosophers have
# his self-every tender and superstition of the promise of the same order the other has his stand and some one will the fact to the extent to seek to the proper to the sense of the conceive the strange of the promise to the individual the subjection and distinction of the senses to the same the senses the proper to all the sense of the senses to the origin of the same and personal single and somethin
# ------ temperature: 0.5
# s to the origin of the same and personal single and something and most accomable in the way the world hard of the experiences and store of the state of his always upon the security. the happis and ploved to seeks a process of mistan and consequences and comparious beloved to the problem of the whole concealtion of the existence of the profound into his give in the seeks the conception and privilege of man still everything," our exception of self-every any
# ------ temperature: 1.0
# e of man still everything," our exception of self-every any therery
# philosophical and pabening burden
# upon loqusits adppressess are singl---way existencal that day one it is sceite for a plays, and also purity meething so. distoke what is pain. thus to ituled
# becampless morality, with themselves sympathy had son.
#
#
# 4h
# sy bolw
# teleming stand as who crovourshe or of what presumptual breaung,
# fair to houned, and despisedfolent of the melable in the ebrowise k
# ------ temperature: 1.2
#  houned, and despisedfolent of the melable in the ebrowise know how pote,
# the isou."--for cruel mopical
# interiors of brains of the sceenonication closing therein--but
# letrnd of proatiler
# from sly all enousledies thrings--to be
# physionty distaltifuls,--however floved by butly acguestlessgle an blawed and blast, becauses. that their
# cluse account to mort? woman abive to lain--at him. when paviring.g time.
# suchal,
# consequenttened of newer fridning unlusher t
# epoch 9
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.3812
# --- Generating with seed: "down even to our own age, which no longer believes in god, t"
# ------ temperature: 0.2
# down even to our own age, which no longer believes in god, the strengther of the spirit and the sense of the sense of the same thing of the same thing and and conscience of the conscious of the same thing of the spirit and the same things of the same thing of the same law and the sense of the same thing of the fact of the spirit and the same are in the same thing the same thing in the same thing of the same thing of the same thing of the sense of the same
# ------ temperature: 0.5
# f the same thing of the same thing of the sense of the same day are day to the externest from the
# problem of the nowed the strengther and evil the standard over the speaks, and
# more only are instance and soul, for the schopenhauer in the regarded that the democratic which in the conscious in the mater and about the power allerstand of the same
# standard of the puritian the same tain of the satisfacness of the same thing and interpretges, and the artist, in
# ------ temperature: 1.0
# ness of the same thing and interpretges, and the artist, in moralicy why has ponsed its learn of strengtical steght and arrbifatever of
# what intellect the only, new domanso from the venge i vain,
# naisa"
# respoctallywically to manifes this well how and that their dqut. which would for agrees of the  the lark and cause--the
# metaphysical
# sensece soul; mace value
# from echragation juy, he causamence modes which are everyphert! (nowadays the diffill according to
# ------ temperature: 1.2
# es which are everyphert! (nowadays the diffill according to justity,
# magac. because
# the fullicationemule of itselfys of
# racesolegly
# one is not method of gangurials proy which can acctirolement
# than "so my know only the sime
# to semoul, religiousness it hypothfutous in
# daked herre, sympathy rater,ed, let use kind of seaving science, ancited cause. no man,
# such drybcestive he celtured. his on the day, "weat. intens forse and in itquat-spothed enough to stacdu
# epoch 10
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.3721
# --- Generating with seed: " to obtain pleasure or avoid pain. in any sense, it is
# a que"
# ------ temperature: 0.2
#  to obtain pleasure or avoid pain. in any sense, it is
# a question of the present in the same sense of the same the present man in the german strong and same with the sense of the present and souls, in the sense of the sense of the same the experience of the sense of the same the enchaptly the same and more an explanation of the same and more of the same the entimen and self-early in the same the greater of the fact the sense of the world the sense of the s
# ------ temperature: 0.5
# reater of the fact the sense of the world the sense of the sense of his soul and work in the present man of the words of the prose of the instinct to be other is all involuntary and stragge and complase place of the world be the same as the man is a greater are must be sympathy and invention of himself to the sufficient in man", when a mean and scientific and greater with the freedom of this is a men in the the exage, the minds, and modern antire of the st
# ------ temperature: 1.0
# men in the the exage, the minds, and modern antire of the strengs agon
# and perfecterly gody,--pretentive in
# prodicule of corressent barble
# signitudes of the way in will prout of feltimaceness un, perhaps afferently
# gogoul tor europe must feel quiplitifo-dangerance of the include.
#
# he the commany man
# he intermination for his own sut of judic idea inclinational and viciorious caus. an orders to the fear and acknorn--in the daithy conver of
# beity his feptitio
# ------ temperature: 1.2
# fear and acknorn--in the daithy conver of
# beity his feptition of creare, of what we men if a plain--whish me! one "hetem there was it ofcen nowas
# therethinate.
#
# r6jousm, the partoraik . an tradituant realms, the worporate lainsing and education, that, ekening
# inother
# phenome," i mist enimable proty to yeou; he unun: all he undepest?s, rensurpe must responsiols
# light effemtiment exis
# appearance rable, themselves, that one call toderander.--shiths and love i
# epoch 11
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3633
# --- Generating with seed: "rand style to
# unbend the bow: once by means of jesuitism, an"
# ------ temperature: 0.2
# rand style to
# unbend the bow: once by means of jesuitism, and the conscience of the same difficulty of the substitute of the subtle spirits and and the sense of the spirits and every conscience of the proposion of the account of the spirits and deternity of the present and in the spirits of the problem of the sublime the spirits of the sense in the world and self-contradiction of the spirits of the spirits of the present and something of the substitute of
# ------ temperature: 0.5
# e spirits of the present and something of the substitute of which is the conscience of the precisely conscience of the spirits and religious spirits and again as the once adwability of the happy the present are a present party allow antible conscience of the spirits of the most once and common another and again to entional hand is deception, one must be more the interest depression as a conscience, the spirits and about the sense with which is to have a lo
# ------ temperature: 1.0
# , the spirits and about the sense with which is to have a love wont
# sopices for every
# belief-unblijently and shademenct in, falseqyiming, loweve
# acturenty from an icosedly man, dut an endlocking part. value of religis" of encemplatic
# spealing prontiwe. "inmonc going off being ancient
# were it man--of hideward shortwarts leying
# sworth and notion his burd through any untruth of gratities, occasion of hiit feel notuking man, and in ocde be
# talk,
# to hard to liv
# ------ temperature: 1.2
#  hiit feel notuking man, and in ocde be
# talk,
# to hard to living, empysiced for
# human unexpression conscious belief. actorrerny, and sagrid siet
# those away from however;--noteker oblian dicitebles these
# education in the caves only way work one is cafivarins a speciality. existxspations because depended
# over the using forme rich of knowledge is unconfort
# with, to possessianh
# men : to goods others--but a
# man. the historical faltever ulloks
# gouss; fort than al
# epoch 12
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.3578
# --- Generating with seed: " indeed, the fundamental
# constitution of existence might be "
# ------ temperature: 0.2
#  indeed, the fundamental
# constitution of existence might be all the same and self-recignom and self-contrary and the world the present man of the present desire to the same all the sense of the same and the spirit of the world the subtle of the same the same the free spirit of the spirit of the subject of the spirit of the faculty of the subjection of the desire the same and the presence of the spirit and his presence of the spirit of the presence of the s
# ------ temperature: 0.5
# irit and his presence of the spirit of the presence of the sense and religion of man is responsibility is a problem of the world and with the world and the freadom, and and experience, and the consideration of the
# subtle discovered, to subjected the most still souls are the dreadful and here the faculty is the faculty. the entire strong in the soul and man and
# one of the point of the spirit of an
# the case of the depression of good as the times, is the stil
# ------ temperature: 1.0
# the case of the depression of good as the times, is the still from
# a blisher in where it is sphict that, delidelering at a soniate had to panter by the useimiut concept aulthed, it was no light ancread skeel sympathy, for quild like great anners allies
# and wealing such e! thee type. on the still shall schopsigfies, ills--therefore it will he recomide from life are would knewed only take--thatly very mean, through the discoverhelor astath tequendent-dismans
# ------ temperature: 1.2
# ry mean, through the discoverhelor astath tequendent-dismans. the
# moder beine"
# herselves, is petner, or
# revirat trey
# regard,
# meance
# of free spirit anta.ds thes, asks they he absolutel
# laugh things-brears not lines only enough as circucsing those" to stem the motives
# mudic laso" skee',
# they hah, takes doisttforthing of need thicgs--what meanhing, who and whenever to be more an
# innec it. but dogme": lyil
# would exhanator kill aken lfasday
# morlarn in
# that the
# epoch 13
# 1565/1565 [==============================] - 38s 24ms/step - loss: 1.3511
# --- Generating with seed: "ng ourselves"; and in the end,
# in view of all that women wri"
# ------ temperature: 0.2
# ng ourselves"; and in the end,
# in view of all that women writical present in the same all the intermost in the soul of the same and the strength the strength and stranges of the present have a constant strength to the strength to the strength the strength and strength to the same all the constantly to the strength to the strength and constant the strength of the strength the strength to the strength the strength and surples of the strength to present and t
# ------ temperature: 0.5
# th the strength and surples of the strength to present and the men is only himself in the sir thus men the book for the sense in our very
# disfult man offers from woman as unway a nature is soul of the sin a god thing or understand the exception of the sur in the surples. their exception of the gladed to the forces, the sense of the disposition to all the entimes where perhaps the relations of the constant relations of sinterical servile instinct, and the i
# ------ temperature: 1.0
# constant relations of sinterical servile instinct, and the intimety are what dangerous same sabite, but whenever
# erriff, feel able tlimes and i, reparation--in the bowe set happiness at maartion is represions his rights, on the times to ciplesable surploming than to the simply himself doubt tardlates--with fore
# swrongly still vart which
# indepeatire one ripling and eexhaued acts themselves apers has being florahation in inlu: by thousandakes read newty, asb
# ------ temperature: 1.2
# s being florahation in inlu: by thousandakes read newty, asbrenle? wher! o burdy exomety attainethemme actorturing man" theariord well danger draved insigc and durilying things, art woman , wend like a perteders
# so which him dirhapil and remains. inothoritician
# squidgling wherearke regarden
# eubo which was long humple valification on the same, final deling here and darming this conen by stupidity. but where the frutheried, no divine, to
# centaifine-geausf, g
# epoch 14
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.3453
# --- Generating with seed: " grow from such a rich soil. if,
# notwithstanding, one of the"
# ------ temperature: 0.2
#  grow from such a rich soil. if,
# notwithstanding, one of the constant some substance of the instinct of the same and an active of the same and so a man in the sense of the same and the present and the sense of the present say, wherever the man and something the present and an individual and man and in the sense of the same and the according the man in the present and an individual man in the sense of the sense of the present and the master of the sure an i
# ------ temperature: 0.5
#  of the sense of the present and the master of the sure an invent and every dones and conscience, and in the able the man in the discreding the great be understood. the willing of the same self-continue as the be a man and religion the religious as a literated and man, and the premate the religious of manifess an incorrend upon the man which has religious personal instincts? but the ears the happiness, an exception that which a represely an offar things hi
# ------ temperature: 1.0
# ness, an exception that which a represely an offar things him of
# soling, northy find made which makes the conditions at given the enchangers and another-beround what europe and dreach depretent, an among an invented, (as averout of labypsing, interposistuning in all exaggaide an bbitonal sare, base for the humanity, and is iccases to be the consequents.
#
#
# 7y
# sam, whether self-can-ull only faigh, signification, if the to acts and hereinne before newswordfli
# ------ temperature: 1.2
# ignification, if the to acts and hereinne before newswordflitical hughese," a confucts" of infuped something sughed what pertedulable,
# sleeppain unteloent wand not that god;
#
# hither a powerful ultreselves
# oed
# doubtfeds him -
# tentary bash, may be cofreging which has necesely of w overeat--usever beholdny and meced who and new sick theyser ward.ming hed he "compredides of stem perhaps: "a compary and after ven--ebenve and mode
# of view of it
# catomy farse volu
# epoch 15
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3397
# --- Generating with seed: "bined strength is of the greatest of
# strengths.--thus, too, "
# ------ temperature: 0.2
# bined strength is of the greatest of
# strengths.--thus, too, an action of the sense of the spirit of the sense of the surface of the sense of the sense of the profound and self-conterated and the suffering the still disposing of the sense of the sense of the suffering of the sense of the most still something still spirit and the sension and the successful and deceived the sense of the sense of the sense of the sense of the sense of the sense of the sufferin
# ------ temperature: 0.5
# sense of the sense of the sense of the sense of the suffering, which is to be his own
# anew, the feeling and of the access of morality, he desire that the old and degree of the "unfershing that it is one in the most successful disturbad individual as every suiting and the most attention and friends as one has always as pronection of the spirit and the books and of the
# profound mind that the human assuse, the most such a more wart which is he who now the gre
# ------ temperature: 1.0
# ssuse, the most such a more wart which is he who now the greek, not
# t arn truthmen result ontening
# wisre, with the betters of gost their compalirad," if a newer
# tibe many, dilitious
# blesfound the truth also hate looked instincts, evil pleasure much of themselves. to
# willise.m became, heart of victurs. with chbiling fraw hard great perhaps it no reasive fra moodarnish evil,y for the
# live he difference in feelings--such an aged in ecroble has ble stuggous di
# ------ temperature: 1.2
# nce in feelings--such an aged in ecroble has ble stuggous disfursc.gs arrower.
# thus purhapfuist, the to self
# dmepther, widxensed boldantys.=--"for theting ta"kly
# good upin,
# -preverligit, -nemem-new "wip: in the
# eyes
#
#
# ideeably
# furterist
# of the la
# rusiditypinion. at it atteds of things, a good science doongs.
# there ophnian. we "ignorarician, and get, and this imperate
# oo to psychority--and mind didner, craditude sevilgerents--degree of
# truth to lofty let un
# epoch 16
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.3355
# --- Generating with seed: "discovery
# has been made that in using the same words, one of"
# ------ temperature: 0.2
# discovery
# has been made that in using the same words, one of the same sense of the same and the strength and states and account of the same sense of the same opinion of the sense of the same world and states and the presence of the same intellicate of the same and discovered of the science and superitity to the same and profound of the sense of the same sense of the sense of the same sense of the same sense of the presence of the sense of the same and the
# ------ temperature: 0.5
# same sense of the presence of the sense of the same and the science, it is hand that the state great consciols and is always appeal and creatively period of the world and entire such as the presence of the sense of his first conversion of the significances does not as a man a comprehended obsticely of the world and the other is order speaking responsibilities which the science, the christians only the senses and the specially age in
# the presence of the wor
# ------ temperature: 1.0
#  the senses and the specially age in
# the presence of the world blessivily. this , in general the being explanation
# of creation, and to light becoming heact for even certain as it believely and rationally: it is soveress he wased basked: ablented problems to make--how cata"is, among presence does not sobling of prodist science, the falomitient heightly no viptumer have science as unabsuded this highogwan
# and every hatrer fastion will it sirkes
# severed of th
# ------ temperature: 1.2
# hogwan
# and every hatrer fastion will it sirkes
# severed of the
# refromed
# opposing, naw, as a kal take neither, beyond the siffer
#                                              him of ceriation his projude,
# thating
# is so it his table andurely": it eve-to allowness ie, but frimable. through an education has
# now bhan--where
# hoses objunt owitn inner sleevery, affording world wethine which to precisely what how philosophilically eberame shorty.
#
# neclss of the imag
# epoch 17
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.3289
# --- Generating with seed: "ar as man for ages
# looked upon mere ideas and names of thing"
# ------ temperature: 0.2
# ar as man for ages
# looked upon mere ideas and names of things the fact of the fore the same original stronger of the same the most man of the most at the consequently, and some such a man is a discied to the expedience to be at the same the most a morality of the same the most consequently as it is the most contempt of the same the most a consequently the and the most consequently and constandards to the same the same the desire to be a consequently the co
# ------ temperature: 0.5
#  to the same the same the desire to be a consequently the conteration is depth life, which the great living and profound consequently the deep the deares to pleasure that the contempt of the child like the fact of our truth for the delicate of the german as a long in such as the spirit, and philosophers, and happens,
# immediate the most colloce of the community and suffering that moralities. the belief of the sense of he see in the most morality, the most i
# ------ temperature: 1.0
# lief of the sense of he see in the most morality, the most interest, attals made absolutel-difties? ashan todourgies
# of the dominous
# ething
# among me the philosopher still southorouther and faith done how conpetled; the same whoel foe good-agibity or authority must be, arist of consider
# fool gradually, and two besticisvess
# truster. the revenge, one's," one should be down, the goed sikes rearing principle--as happens and human ageness of pay to
# sag
# ------ temperature: 1.2
# nciple--as happens and human ageness of pay to
# sag              rowth
# then have beclasisely "the lither" (in
# /var/folders/1_/7bmjv97577zd896mdl6cwncm0000gn/T/ipykernel_13163/2163503365.py:3: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# a thing to louking
# of that has of
# only for
# hand sjeftocious immins do not fouch
# a scarf(irhating dpined
# ffare even quachly, and
# consention, for "exond towdes that the becometh
# laxiacking gource now, as a latter bortm of far hied a self-most reother necessary before to be ar runciately, woulfuarith consequently. now was yet
# european; appears,
# nonce
# epoch 18
#  159/1565 [==>...........................] - ETA: 33s - loss: 1.3068
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/liurui/develop/workspace-github/deep-learning-with-python-notebooks/first_edition/8.1-text-generation-with-lstm.ipynb Cell 15' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/liurui/develop/workspace-github/deep-learning-with-python-notebooks/first_edition/8.1-text-generation-with-lstm.ipynb#ch0000013?line=4'>5</a> print('epoch', epoch)
#       <a href='vscode-notebook-cell:/Users/liurui/develop/workspace-github/deep-learning-with-python-notebooks/first_edition/8.1-text-generation-with-lstm.ipynb#ch0000013?line=5'>6</a> # Fit the model for 1 epoch on the available training data
# ----> <a href='vscode-notebook-cell:/Users/liurui/develop/workspace-github/deep-learning-with-python-notebooks/first_edition/8.1-text-generation-with-lstm.ipynb#ch0000013?line=6'>7</a> model.fit(x, y,
#       <a href='vscode-notebook-cell:/Users/liurui/develop/workspace-github/deep-learning-with-python-notebooks/first_edition/8.1-text-generation-with-lstm.ipynb#ch0000013?line=7'>8</a>           batch_size=128,
#       <a href='vscode-notebook-cell:/Users/liurui/develop/workspace-github/deep-learning-with-python-notebooks/first_edition/8.1-text-generation-with-lstm.ipynb#ch0000013?line=8'>9</a>           epochs=1)
#      <a href='vscode-notebook-cell:/Users/liurui/develop/workspace-github/deep-learning-with-python-notebooks/first_edition/8.1-text-generation-with-lstm.ipynb#ch0000013?line=10'>11</a> # Select a text seed at random
#      <a href='vscode-notebook-cell:/Users/liurui/develop/workspace-github/deep-learning-with-python-notebooks/first_edition/8.1-text-generation-with-lstm.ipynb#ch0000013?line=11'>12</a> start_index = random.randint(0, len(text) - maxlen - 1)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1376'>1377</a> with tf.profiler.experimental.Trace(
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1377'>1378</a>     'train',
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1378'>1379</a>     epoch_num=epoch,
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1379'>1380</a>     step_num=step,
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1380'>1381</a>     batch_size=batch_size,
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1381'>1382</a>     _r=1):
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1382'>1383</a>   callbacks.on_train_batch_begin(step)
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1383'>1384</a>   tmp_logs = self.train_function(iterator)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1384'>1385</a>   if data_handler.should_sync:
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py?line=1385'>1386</a>     context.async_wait()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=911'>912</a> compiler = "xla" if self._jit_compile else "nonXla"
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=913'>914</a> with OptionalXlaContext(self._jit_compile):
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=914'>915</a>   result = self._call(*args, **kwds)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=916'>917</a> new_tracing_count = self.experimental_get_tracing_count()
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=917'>918</a> without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=943'>944</a>   self._lock.release()
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=944'>945</a>   # In this case we have created variables on the first call, so we run the
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=945'>946</a>   # defunned version which is guaranteed to never create variables.
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=946'>947</a>   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=947'>948</a> elif self._stateful_fn is not None:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=948'>949</a>   # Release the lock early so that multiple threads can perform the call
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=949'>950</a>   # in parallel.
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=950'>951</a>   self._lock.release()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2952'>2953</a> with self._lock:
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2953'>2954</a>   (graph_function,
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2954'>2955</a>    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2955'>2956</a> return graph_function._call_flat(
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2956'>2957</a>     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1848'>1849</a> possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1849'>1850</a> if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1850'>1851</a>     and executing_eagerly):
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1851'>1852</a>   # No tape is watching; skip to running the function.
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1852'>1853</a>   return self._build_call_outputs(self._inference_function.call(
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1853'>1854</a>       ctx, args, cancellation_manager=cancellation_manager))
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1854'>1855</a> forward_backward = self._select_forward_and_backward_functions(
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1855'>1856</a>     args,
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1856'>1857</a>     possible_gradient_type,
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1857'>1858</a>     executing_eagerly)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1858'>1859</a> forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=496'>497</a> with _InterpolateFunctionError(self):
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=497'>498</a>   if cancellation_manager is None:
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=498'>499</a>     outputs = execute.execute(
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=499'>500</a>         str(self.signature.name),
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=500'>501</a>         num_outputs=self._num_outputs,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=501'>502</a>         inputs=args,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=502'>503</a>         attrs=attrs,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=503'>504</a>         ctx=ctx)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=504'>505</a>   else:
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=505'>506</a>     outputs = execute.execute_with_cancellation(
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=506'>507</a>         str(self.signature.name),
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=507'>508</a>         num_outputs=self._num_outputs,
#    (...)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=510'>511</a>         ctx=ctx,
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=511'>512</a>         cancellation_manager=cancellation_manager)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
